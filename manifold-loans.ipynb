# %%
# Manifold Markets tool for user loan statistics
# this is slow since it has to go through each market to find which ones are resolved
# use manifolio instead for just the loan amount (it is much faster!)

# %%
###############################
# Get user loan info from API #
###############################

####### CONFIG ##########
# Manifold username
username = 'parhizj'
# Manifold Market API key
api_key = "YOUR-API-KEY"
#########################

import requests
import time
import os
import json
from datetime import datetime

bets_url_by_username = 'https://manifold.markets/api/v0/bets?username='
market_url_by_id = 'https://manifold.markets/api/v0/market/'
json_filepath = 'manifold-loans-bets-all.json'
# store a list of resolved markets as a cache (only when isResolved is True)
market_resolved_cache_filepath = 'manifold-resolved-cache.json'

# API request headers
headers = {
    "Authorization": f"Key {api_key}",
}

# %%
# 1 second delay between requests
def get_username_bets_before(user_name, before=None):
    bets_before = []
    # for first run
    orig_url = bets_url_by_username + user_name
    url = orig_url
    total_count = 0
    if before is not None:
        url += '&before=' + before
    while url:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            num_bets = len(data)
            if isinstance(data, list) and num_bets > 0:
                last_bet_id = None
                for bet in data:
                    if isinstance(bet, dict) and "id" in bet:
                        before = bet["id"]
                        total_count += 1
                        bets_before.append(bet)
                time.sleep(1)  # Delay between requests to avoid hammering
                # assume the last bet is the oldest one in the JSON
                url = orig_url + '&before=' + before
            else:
                if isinstance(data, dict) and 'error' in data:
                    print("Error, data from API not a list or no data: {data}")
                url = None
            if num_bets < 1000:
                # requested a 1000, so if there is less we have hit the end of the bets
                url = None
        else:
            url = None
    return bets_before

def get_market_is_resolved(market_id):
    bets_before = []
    # for first run
    url = market_url_by_id + market_id
    response = requests.get(url, headers=headers)
    isResolved = get_market_cached(market_id)
    if isResolved:
        return True
    if response.status_code == 200:
        data = response.json()
        if 'isResolved' in data:
            isResolved = data['isResolved']
            if isResolved:
                write_market_cached(market_id)
        time.sleep(1)
    return isResolved

def get_market_cached(market_id):
    if os.path.exists(market_resolved_cache_filepath):
        with open(market_resolved_cache_filepath, 'r') as f:
            cache = json.load(f)
            if market_id in cache:
                return True
    return False

def write_market_cached(market_id):
    cached_data = []
    if os.path.exists(market_resolved_cache_filepath):
        with open(market_resolved_cache_filepath, 'r') as f:
            cached_data = json.load(f)
    else:
        print("Creating new file cache for resolved markets.")
    try:
        if market_id not in cached_data:
            cached_data.append(market_id)
            with open(market_resolved_cache_filepath, 'w') as f:
                json.dump(cached_data, f)
    except:
        return False

# %%
bets = get_username_bets_before(username)

# %%
if bets is not None:
    with open(json_filepath, 'w') as f:
        json.dump(bets, f)

# %%
with open(json_filepath, 'r') as f:
    all_bets = json.load(f)

bets_by_contract = {}
for bet in all_bets:
    if 'loanAmount' in bet and 'contractId' in bet:
        contractId = bet['contractId']
        contractBets = []
        if contractId in bets_by_contract:
            contractBets = bets_by_contract[contractId]
        contractBets.append(bet)
        bets_by_contract[contractId] = contractBets
totalLoans = 0
contractNetLoans = {}
open_bets = []
open_contracts = {}
for contract_id, bets in bets_by_contract.items():
    contractLoan = 0
    # get resolved status (only consider not resolved)
    isResolved = get_market_is_resolved(contract_id)
    if isResolved is False:
        open_contracts[contract_id] = bets
        for bet in bets:
            open_bets.append(bet)
            if 'loanAmount' in bet:
                contractLoan += bet['loanAmount']
        # print(f"Contract net loan for {contract_id}: {contractLoan:1.0f}")
    contractNetLoans[contract_id] = contractLoan
    totalLoans += contractLoan
    
sorted_contractNetLoans = dict(sorted(contractNetLoans.items(), key=lambda x:x[1], reverse=True))
for contract_id, loanAmount in sorted_contractNetLoans.items():
    if loanAmount >= 0.5:
        print(f"Contract net loan for {contract_id}: {loanAmount:1.0f}")
# Out:
# Contract net loan for w8Axni4eMBky1Mg0IxIL: 105
# Contract net loan for DgT3wPneFl9GPjC9MUFw: 95
# Contract net loan for cpGe9ErhdnZ5yhjzGEpO: 89
# Contract net loan for SZQH87RNsqa1kplkPn5F: 75
# Contract net loan for sG9xUB5jxzmUHZWkSW0d: 41
# Contract net loan for fyZff32mPbXBxd5IfWeq: 40
# Contract net loan for NNsQvVXnJwhYaSWNrIT0: 39
# Contract net loan for ePuLMhmIC1XSHIMjDJeN: 33
# Contract net loan for 6F5ZEC3VpY9WY6C3Ay7i: 32
# Contract net loan for BKx2ha4LBj5uQpD4bdO2: 31
# Contract net loan for Bjz06YJmRycbfbkE8anm: 30
# Contract net loan for avgjyL9FAWEmeaGEbFyM: 28
# Contract net loan for ieIbqFDlQlnKh7PKAQT1: 28
# Contract net loan for onMAJ1OtuHSRdIXwxW2p: 25
# Contract net loan for dib8XAR3WIdrAz9RgFnn: 25
# Contract net loan for SVk1ZnhV2A7ZL3CEn3SB: 24
# Contract net loan for 6zqhpoEPAWXalDUGwsPp: 24
# Contract net loan for nNYuLGSNC3cE443aabHa: 23
# Contract net loan for OlGXVx60s2I5f8UbMiF1: 22
# Contract net loan for gjRZMDHlowmhOVua6RiS: 21
# Contract net loan for L7pS83AxLgr0OTC2h4F5: 21
# Contract net loan for AgQlbfTTXU3F6mjM2rTQ: 21
# Contract net loan for 6qwQWnb76xm0XJmFneFF: 21
# Contract net loan for aiEC7iAVQDWs2u2vwFVH: 20
# Contract net loan for vKZUxybbx1OnaklIO5CN: 19
# Contract net loan for iorzfK5rIhz6EL56biZd: 19
# Contract net loan for Ers4lf7h8ICdxeDm8L0n: 19
# Contract net loan for 0ervOdcgwaf8HqJJmMCx: 19
# Contract net loan for WJ2qV3tMYAe14erwZuF4: 18
# Contract net loan for KTCwFDqKPTZ4Er7c4Dnx: 18
# Contract net loan for sZSo5GkhpKFFLoxipwiI: 18
# Contract net loan for 3YzevhxtAYNQuQVil1K3: 17
# Contract net loan for o1I7XfoRZtZAut7wXF0n: 16
# Contract net loan for 3WkSuFEFNDpYGkAzhVkc: 15
# Contract net loan for HIolh4Yv2Xaj8poryp30: 14
# Contract net loan for MefsjVnWWU7ExA5wzdj0: 14
# Contract net loan for QbjCZSbG6xfxVpgyp0ZR: 13
# Contract net loan for khUuIaOxjIzllVvf2yFr: 13
# Contract net loan for 9dG1dOOvfFZeFkhTCVT9: 13
# Contract net loan for 7GfbxKAYyMjZZqLkv2R5: 12
# Contract net loan for H9emVeEKVr9EHMckhM2i: 12
# Contract net loan for lqDz6qnr42aiDGUZmrjY: 12
# Contract net loan for kCpQBFYYU193aYapoVSR: 12
# Contract net loan for vRb0gmEfsv1iRflshHgB: 12
# Contract net loan for Qmi6qcotaHJCzVa0lf0G: 12
# Contract net loan for NM36vpBaxYc7Sbs8czrU: 12
# Contract net loan for S5LGFTDxqPgVs9Vv4gTs: 12
# Contract net loan for f3M3czQBZQykdFEecOmR: 12
# Contract net loan for sK6jhPERlI0FSTdszm7p: 11
# Contract net loan for etka6V8IgKYg9AGQdJrv: 11
# Contract net loan for xzgHKgmZdZO2FNtwXN6I: 11
# Contract net loan for 2V4mFj9ngyjvgQvoKTI3: 11
# Contract net loan for C8MtRn2ixX8Y0rV2Oqcy: 10
# Contract net loan for yRDixgBdgGEv5DKlz5Yn: 9
# Contract net loan for aNlsrzvidkGcveSdz1EY: 8
# Contract net loan for oXV50wDDIVcMtM0aQDZO: 8
# Contract net loan for 9mRItb0konMPN8WTR3h6: 8
# Contract net loan for 8g1uP95LBg8HAKQ5c3ji: 8
# Contract net loan for QmB5lddNV6y584os08s2: 8
# Contract net loan for 3KlDghuIDaDSz2wM5doB: 8
# Contract net loan for 0tDi58HufD6nrjcptplN: 7
# Contract net loan for cW32aRgu4AWbmCxe8Z1s: 7
# Contract net loan for hycNvubKoyojmKowID5g: 7
# Contract net loan for i4JjxKGL5FpOjVghX5tN: 7
# Contract net loan for UnhjvWLFiLMOSypyVX1V: 7
# Contract net loan for 4MkPyu5D9MRLPREODSD7: 7
# Contract net loan for TiUdxGs8Qx6Tgagb2vW1: 7
# Contract net loan for Xy43mYhlRJOJCEfD74SN: 7
# Contract net loan for nP7DSO61cjBPtFQjZXzJ: 7
# Contract net loan for B03GxohOPJUT8nUpjNx7: 7
# Contract net loan for EabkJNBc6Z7ggmQ63uiq: 7
# Contract net loan for YvVqSYEdyiYn7Mdj4oCc: 7
# Contract net loan for udbduPId3u46rjEivqQV: 6
# Contract net loan for bC2UnVdPUVg34zuYBza7: 6
# Contract net loan for gRasOeJ3NN7aFnn5mnO0: 6
# Contract net loan for cL48MaJsH11ZNmUqsMwG: 6
# Contract net loan for SXE20aE0FKKBsra4WAOj: 6
# Contract net loan for ZJ0qemC1Q4ogSXHiTXGd: 6
# Contract net loan for 8wJpf4C9hUN3OoBuCpHw: 5
# Contract net loan for c4GHtaaybANa1JlC7NsR: 5
# Contract net loan for RPz0R7GkULbrKnCuYTkK: 5
# Contract net loan for GDTxwSXy07yf77Fj7XQq: 5
# Contract net loan for eaCjqjITTYRu7Hy1gVGq: 5
# Contract net loan for hYheptUWBmOPmrAeAKtK: 5
# Contract net loan for 0wlu71Dx7Z9KC5pLSk2d: 5
# Contract net loan for GQvRyp7rVb4s8cldI0ow: 5
# Contract net loan for TevLYj3vEsJxCZXhjOfp: 5
# Contract net loan for 0jnshEOMPWGqnZ6O96AU: 5
# Contract net loan for 0WXQpGstjUkT6HxhAtnG: 5
# Contract net loan for uajEabYJu0TWCGtJm0ff: 5
# Contract net loan for e3ah02wnqsS2hwQYTgQs: 5
# Contract net loan for FTGtsTMjv5zNxVMoZuKK: 4
# Contract net loan for yXyKRryZwBMCDO36VNZS: 4
# Contract net loan for PQ6Omz0JbsL7xGtGlEhl: 4
# Contract net loan for o9DLBgXZZbsDjda1iDB8: 4
# Contract net loan for 2BlkWeBS6cgrRVqRbaEW: 4
# Contract net loan for zmt5UC3dPb20vFpjjcUq: 4
# Contract net loan for KSFaggN30fP5hnsx01qL: 4
# Contract net loan for psr7IRurMI9yDmzdvnGx: 4
# Contract net loan for Dc5e4sHcQxSbZp1G24pD: 4
# Contract net loan for lm9I9rJ2CHBQsyPo5vcY: 4
# Contract net loan for LcTYGScuULbbLHDEWY7C: 4
# Contract net loan for ERppXBTsbgs2mN2DCMwG: 4
# Contract net loan for 4amdGgZFKTxUMC3Fym6F: 4
# Contract net loan for UBeSmb8OzbtaB6vbzYOK: 3
# Contract net loan for m2Hjaz92dq407pYmku98: 3
# Contract net loan for eRo29BUNod3rEZsqIMS9: 3
# Contract net loan for kbZh2TaR5QzgyGcta9lF: 3
# Contract net loan for 3hnINl46t77RAVDeTDUJ: 3
# Contract net loan for xw7KFj6lb4LaGA30Z1pA: 3
# Contract net loan for fghnrqtqvC2uefyMTz77: 3
# Contract net loan for Zn6S6CWvmLJmOGSkFNEh: 3
# Contract net loan for cBm7e6asIOHO1wHSn8ez: 3
# Contract net loan for xiQoP9cLqioCpwZSSPaL: 3
# Contract net loan for vQvG8ahzRiDT1bnDlftF: 3
# Contract net loan for fbreESAXj3as7xl4FhRv: 3
# Contract net loan for hqTneuDcF7jXJt4tEHlj: 3
# Contract net loan for oqGvCAwOvaI2qTG1rvPg: 3
# Contract net loan for OqNFSXQ47TwMv3AjPWuL: 3
# Contract net loan for fwVZFooHYhplzBuSjpgg: 3
# Contract net loan for 9xuvDad1bxNGrd9Jx0vq: 2
# Contract net loan for wG2Oo9T0wK9jBXe7DMWB: 2
# Contract net loan for KXum4vg3N0dEjGFyCmMS: 2
# Contract net loan for 39U0r7NjAIlHomiViCJd: 2
# Contract net loan for yFK3MR8ZZtuPe6NDcRZO: 2
# Contract net loan for KYVIsmaCwGO1NlqKiGDF: 2
# Contract net loan for lizjcNHxvxyWJMrFGSqj: 2
# Contract net loan for Uv4dUN7dUne8T7syirmf: 2
# Contract net loan for NY80YgcbuNTMJcYRx58M: 2
# Contract net loan for 7B7gGRjh0tx6P5LI0hEE: 2
# Contract net loan for XoOYg93LDvZQa7fL2dLr: 2
# Contract net loan for XtE0NfHCUEXkDz8aLjo6: 2
# Contract net loan for fmFSnuEfOVOSf3lahY0H: 1
# Contract net loan for Eb6Hha4x7ovJHxJokBre: 1
# Contract net loan for icv0CsOEWTAL5XS0WoOu: 1
# Contract net loan for NKFVr2TBjF3W07z67lg0: 1
# Contract net loan for XmhHOLiAi8Zjn8EeJLy5: 1
# Contract net loan for RAXkxUa07M7RXIeawJuB: 1
# Contract net loan for 9Uf2vt3UDZsG9CY4wpqS: 1
# Contract net loan for TOt7tHwocwnypWQRtqfC: 1
# Contract net loan for iF67BPCQnsb4ot6tGOFC: 1
# Contract net loan for XILSrzEwudhTRRdET9lm: 1
# Contract net loan for IY2LunPmeMiY5nr4yKec: 1
# Contract net loan for Biad3YIGyf1DGinpL2Wf: 1
# Contract net loan for CRNIlkQqEkYyCwpVNGQC: 1
# Contract net loan for 3MmcabM19WBFbkhn44A2: 1
# Contract net loan for ja3qjPInUcXJRdtvUFHa: 1
# Contract net loan for 2RMxiT2LrvaPUt9orPt6: 1

# %%
print(f"# Bets (All): {len(all_bets)}")
print(f"# Bets (Not resolved): {len(open_bets)}")
print(f"Contracts (All): {len(bets_by_contract)}")
print(f"Contracts (Not resolved): {len(open_contracts)}")
print(f"Net loan amount: {totalLoans:1.0f}")
# Out:
# # Bets (All): 7774
# # Bets (Not resolved): 2378
# Contracts (All): 374
# Contracts (Not resolved): 173
# Net loan amount: 1696
